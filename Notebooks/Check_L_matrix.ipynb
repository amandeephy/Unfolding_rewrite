# %%
import ROOT
import uproot
import numpy  as np
import mplhep as hep
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
file = uproot.open('/scratch/brown/bakshi3/TopSpinCorr_Run2_generalized_ND/CMSSW_10_6_30/src/TopAnalysis/Configuration/analysis/diLeptonic/TUnfoldResults_2016postVFP/Nominal/combined/c_rr_mttbar.root')

# %%
plt.figure(figsize=(8,6))
hep.hist2dplot(np.abs(file['c_rr_mttbarLMatrix;1'].values().T @ file['c_rr_mttbarLMatrix;1'].values()), norm=mpl.colors.LogNorm())
# Out:
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f9a6a8d8490>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f9a6a8d8790>, text=[])
