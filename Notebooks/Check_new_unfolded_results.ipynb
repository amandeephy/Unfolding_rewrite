# %%
import ROOT
import uproot
import numpy as np
import matplotlib.pyplot as plt

# %%
BASE_DIR = '/depot/cms/top/bakshi3/TopSpinCorr_Run2_generalized_ND/CMSSW_10_6_30/src/TopAnalysis/Configuration/analysis/diLeptonic/UnfoldingHistos_2017/Nominal/ee/'

# %%
uproot_fileptr = uproot.open(BASE_DIR + 'histosTUnfold_ee_ttbarsignalplustau_fromDilepton_2017UL.root')

# %%
uproot_fileptr.keys()
# Out:
# ['hNrOfEvts;1',
#  'hreco_top_pt;1',
#  'hreco_l_pt;1',
#  'hreco_lbar_pt;1',
#  'hreco_ttbar_pt;1',
#  'hreco_ttbar_mass;1',
#  'hreco_ttbar_delta_phi;1',
#  'hreco_ttbar_delta_eta;1',
#  'hreco_ttbar_rapidity;1',
#  'hreco_llbar_pt;1',
#  'hreco_llbar_mass;1',
#  'hreco_b1k;1',
#  'hreco_b2k;1',
#  'hreco_b1j;1',
#  'hreco_b2j;1',
#  'hreco_b1r;1',
#  'hreco_b2r;1',
#  'hreco_b1q;1',
#  'hreco_b2q;1',
#  'hreco_b1n;1',
#  'hreco_b2n;1',
#  'hreco_c_kk;1',
#  'hreco_c_rr;1',
#  'hreco_c_nn;1',
#  'hreco_c_rk;1',
#  'hreco_c_kr;1',
#  'hreco_c_nr;1',
#  'hreco_c_rn;1',
#  'hreco_c_nk;1',
#  'hreco_c_kn;1',
#  'hreco_c_Prk;1',
#  'hreco_c_Mrk;1',
#  'hreco_c_Pnr;1',
#  'hreco_c_Mnr;1',
#  'hreco_c_Pnk;1',
#  'hreco_c_Mnk;1',
#  'hreco_c_kj;1',
#  'hreco_c_rq;1',
#  'hreco_c_rj;1',
#  'hreco_c_jr;1',
#  'hreco_c_Prj;1',
#  'hreco_c_Mrj;1',
#  'hreco_c_han;1',
#  'hreco_c_sca;1',
#  'hreco_c_tra;1',
#  'hreco_c_kjL;1',
#  'hreco_c_rqL;1',
#  'hreco_c_rkP;1',
#  'hreco_c_rkM;1',
# ...

# %%
[k for k in uproot_fileptr.keys() if 'llbar_delta_eta' in k]
# Out:
# ['hreco_llbar_delta_eta;1',
#  'hreco_llbar_delta_eta_mttbar;1',
#  'hreco_llbar_delta_eta_top_pt;1',
#  'hreco_llbar_delta_eta_top_scatteringangle_ttbarframe;1',
#  'hrecoBootstrap_llbar_delta_eta0;1',
#  'hgen_llbar_delta_eta;1',
#  'hgen_llbar_delta_eta_mttbar;1',
#  'hgen_llbar_delta_eta_top_pt;1',
#  'hgen_llbar_delta_eta_top_scatteringangle_ttbarframe;1',
#  'hvisgen_llbar_delta_eta;1',
#  'hvisgen_llbar_delta_eta_mttbar;1',
#  'hvisgen_llbar_delta_eta_top_pt;1',
#  'hvisgen_llbar_delta_eta_top_scatteringangle_ttbarframe;1',
#  'hrecoVsgen_llbar_delta_eta;1',
#  'hrecoVsgen_llbar_delta_eta_mttbar;1',
#  'hrecoVsgen_llbar_delta_eta_top_pt;1',
#  'hrecoVsgen_llbar_delta_eta_top_scatteringangle_ttbarframe;1',
#  'hresolutionbins_llbar_delta_eta;1']

# %%
uproot_fileptr['hgen_llbar_delta_eta'].to_hist().plot()
# Out:
# /home/bakshi3/.conda/envs/cent7/2020.11-py38/venv/lib/python3.10/site-packages/mplhep/utils.py:211: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   warnings.warn(
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f0ad2a4ac50>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
uproot_fileptr['hreco_llbar_delta_eta_mttbar'].to_hist().plot()
# Out:
# /home/bakshi3/.conda/envs/cent7/2020.11-py38/venv/lib/python3.10/site-packages/mplhep/utils.py:211: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   warnings.warn(
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f0ad28f8ee0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
uproot_fileptr['hreco_c_Pnk_mttbar'].to_hist().plot()
# Out:
# /home/bakshi3/.conda/envs/cent7/2020.11-py38/venv/lib/python3.10/site-packages/mplhep/utils.py:211: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   warnings.warn(
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f0ad30dc8e0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
ROOT_fileptr = ROOT.TFile.Open(BASE_DIR + 'histosTUnfold_ee_ttbarsignalplustau_fromDilepton_2017UL.root', 'READ')

# %%
# %jsroot

# %%
hgen_llbar_delta_eta = ROOT_fileptr.Get('hgen_llbar_delta_eta')

# %%
c = ROOT.TCanvas()
hgen_llbar_delta_eta.Rebin(2)
hgen_llbar_delta_eta.Draw()
c.Draw()
# Out:
# <div id="root_plot_1675486613198"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1675486613198(Core) {
# ...
