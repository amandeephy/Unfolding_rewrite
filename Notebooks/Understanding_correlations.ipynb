# %%
import ROOT
import uproot
import numpy as np
import matplotlib.pyplot as plt

# %%
BASEDIR = '/depot/cms/top/bakshi3/TopSpinCorr_Run2_generalized_ND/CMSSW_10_6_30/src/TopAnalysis/Configuration/analysis/diLeptonic/UnfoldingHistos_2016preVFP/Nominal/emu/'

# %%
fileptr = uproot.open(BASEDIR + 'histosTUnfold_emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP.root')

# %%
fileptr.keys()
# Out:
# ['hNrOfEvts;1',
#  'hreco_top_pt;1',
#  'hreco_l_pt;1',
#  'hreco_lbar_pt;1',
#  'hreco_ttbar_pt;1',
#  'hreco_ttbar_mass;1',
#  'hreco_ttbar_delta_phi;1',
#  'hreco_ttbar_delta_eta;1',
#  'hreco_ttbar_rapidity;1',
#  'hreco_llbar_pt;1',
#  'hreco_llbar_mass;1',
#  'hreco_b1k;1',
#  'hreco_b2k;1',
#  'hreco_b1j;1',
#  'hreco_b2j;1',
#  'hreco_b1r;1',
#  'hreco_b2r;1',
#  'hreco_b1q;1',
#  'hreco_b2q;1',
#  'hreco_b1n;1',
#  'hreco_b2n;1',
#  'hreco_c_kk;1',
#  'hreco_c_rr;1',
#  'hreco_c_nn;1',
#  'hreco_c_rk;1',
#  'hreco_c_kr;1',
#  'hreco_c_nr;1',
#  'hreco_c_rn;1',
#  'hreco_c_nk;1',
#  'hreco_c_kn;1',
#  'hreco_c_Prk;1',
#  'hreco_c_Mrk;1',
#  'hreco_c_Pnr;1',
#  'hreco_c_Mnr;1',
#  'hreco_c_Pnk;1',
#  'hreco_c_Mnk;1',
#  'hreco_c_kj;1',
#  'hreco_c_rq;1',
#  'hreco_c_rj;1',
#  'hreco_c_jr;1',
#  'hreco_c_Prj;1',
#  'hreco_c_Mrj;1',
#  'hreco_c_han;1',
#  'hreco_c_sca;1',
#  'hreco_c_tra;1',
#  'hreco_c_kjL;1',
#  'hreco_c_rqL;1',
#  'hreco_c_rkP;1',
#  'hreco_c_rkM;1',
# ...

# %%
reco_ckj  = fileptr['hreco_c_kj'].to_numpy()[0]
reco_chan = fileptr['hreco_c_han'].to_numpy()[0]

# %%
plt.scatter(reco_chan, reco_ckj)

# %%
fileptr = uproot.open('/depot/cms/top/bakshi3/TopSpinCorr_Run2_generalized_ND/CMSSW_10_6_30/src/TopAnalysis/Configuration/analysis/diLeptonic/BootstrapCorrelationMatrices_1D_newvars_1000PE_FW.root')

# %%
fileptr['h_RhoBBCorrected_rebinnedA'].to_hist().plot()
# Out:
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f1429213250>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f1429213670>, text=[])
