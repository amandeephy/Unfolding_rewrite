# %%
import ROOT
import uproot
import numpy  as np
import mplhep as hep
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
file = uproot.open('/scratch/brown/bakshi3/TopSpinCorr_Run2_generalized_ND/CMSSW_10_6_30/src/TopAnalysis/Configuration/analysis/diLeptonic/TUnfoldResults_2016preVFP/Nominal/combined/b1k_mttbar.root')

# %%
plt.figure(figsize=(8,6))
hep.hist2dplot(np.abs(file['b1k_mttbarLMatrix;1'].values().T @ file['b1k_mttbarLMatrix;1'].values()), norm=mpl.colors.LogNorm())
# Out:
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f3f368e5810>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f3f368e59f0>, text=[])

# %%
file = uproot.open('/scratch/brown/bakshi3/TopSpinCorr_Run2_generalized_ND/CMSSW_10_6_30/src/TopAnalysis/Configuration/analysis/diLeptonic/TUnfoldResults_2016preVFP/Nominal/combined_w_reg_mttbar/b1k_mttbar.root')

# %%
plt.figure(figsize=(8,6))
hep.hist2dplot(np.abs(file['b1k_mttbarLMatrix;1'].values().T @ file['b1k_mttbarLMatrix;1'].values()), norm=mpl.colors.LogNorm())
# Out:
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f3f1ee3fa90>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f3f1ee3fd90>, text=[])
