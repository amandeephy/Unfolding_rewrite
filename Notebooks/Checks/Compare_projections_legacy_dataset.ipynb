# %%
import ROOT
import uproot 
import numpy as np
import matplotlib.pyplot as plt

# %%
BASE_DIR = "/depot/cms/top/jthiema/TopSpinCorr/CMSSW_8_0_26_patch2/src/TopAnalysis/Configuration/analysis/diLeptonic/preunfolded/Nominal/emu"

# %%
b1k_preunfolded = uproot.open(BASE_DIR + "/b1k.root")

# %%
b1k_preunfolded.keys()
# Out:
# ['b1kData;1',
#  'b1kGen;1',
#  'b1kVisGen;1',
#  'b1kReco;1',
#  'b1kRecoBg;1',
#  'b1kRespMat;1']

# %% [markdown]
# ### Project out the axes

# %%
b1k_preunfolded["b1kRespMat"].to_hist()
# Out:
# Hist(
#   Variable(array([-1.        , -0.91666667, -0.83333333, -0.75      , -0.66666667,
#        -0.58333333, -0.5       , -0.41666667, -0.33333333, -0.25      ,
#        -0.16666667, -0.08333333,  0.        ,  0.08333333,  0.16666667,
#         0.25      ,  0.33333333,  0.41666667,  0.5       ,  0.58333333,
#         0.66666667,  0.75      ,  0.83333333,  0.91666667,  1.        ]), name='xaxis'),
#   Variable(array([-1.        , -0.95833333, -0.91666667, -0.875     , -0.83333333,
#        -0.79166667, -0.75      , -0.70833333, -0.66666667, -0.625     ,
#        -0.58333333, -0.54166667, -0.5       , -0.45833333, -0.41666667,
#        -0.375     , -0.33333333, -0.29166667, -0.25      , -0.20833333,
#        -0.16666667, -0.125     , -0.08333333, -0.04166667,  0.        ,
#         0.04166667,  0.08333333,  0.125     ,  0.16666667,  0.20833333,
#         0.25      ,  0.29166667,  0.33333333,  0.375     ,  0.41666667,
#         0.45833333,  0.5       ,  0.54166667,  0.58333333,  0.625     ,
#         0.66666667,  0.70833333,  0.75      ,  0.79166667,  0.83333333,
#         0.875     ,  0.91666667,  0.95833333,  1.        ]), name='yaxis'),
#   storage=Weight()) # Sum: WeightedSum(value=124539, variance=23589.3) (WeightedSum(value=700637, variance=144694) with flow)

# %%
b1k_preunfolded["b1kRespMat"].to_hist().project('xaxis')
# Out:
# Hist(Variable(array([-1.        , -0.91666667, -0.83333333, -0.75      , -0.66666667,
#        -0.58333333, -0.5       , -0.41666667, -0.33333333, -0.25      ,
#        -0.16666667, -0.08333333,  0.        ,  0.08333333,  0.16666667,
#         0.25      ,  0.33333333,  0.41666667,  0.5       ,  0.58333333,
#         0.66666667,  0.75      ,  0.83333333,  0.91666667,  1.        ]), name='xaxis'), storage=Weight()) # Sum: WeightedSum(value=700637, variance=144694)

# %%
b1k_preunfolded["b1kRespMat"].to_hist().project('yaxis')
# Out:
# Hist(Variable(array([-1.        , -0.95833333, -0.91666667, -0.875     , -0.83333333,
#        -0.79166667, -0.75      , -0.70833333, -0.66666667, -0.625     ,
#        -0.58333333, -0.54166667, -0.5       , -0.45833333, -0.41666667,
#        -0.375     , -0.33333333, -0.29166667, -0.25      , -0.20833333,
#        -0.16666667, -0.125     , -0.08333333, -0.04166667,  0.        ,
#         0.04166667,  0.08333333,  0.125     ,  0.16666667,  0.20833333,
#         0.25      ,  0.29166667,  0.33333333,  0.375     ,  0.41666667,
#         0.45833333,  0.5       ,  0.54166667,  0.58333333,  0.625     ,
#         0.66666667,  0.70833333,  0.75      ,  0.79166667,  0.83333333,
#         0.875     ,  0.91666667,  0.95833333,  1.        ]), name='yaxis'), storage=Weight()) # Sum: WeightedSum(value=124539, variance=23589.3) (WeightedSum(value=700637, variance=144694) with flow)

# %% [markdown]
# ## Compare bin by bin contents

# %% [markdown]
# ### Gen

# %%
gen_from_projection = b1k_preunfolded["b1kRespMat"].to_hist().project('xaxis').to_numpy()[0]
gen_from_projection
# Out:
# array([29045.99796112, 29167.02510377, 29155.78057308, 28954.37147581,
#        29075.99688186, 29253.0642014 , 29107.02223828, 29154.65144256,
#        29100.78883557, 29142.35230945, 29261.65178884, 29065.03466746,
#        29178.07281687, 29170.74941395, 29136.45270789, 29283.924991  ,
#        29395.20943281, 29152.2313455 , 29219.4155765 , 29257.90930911,
#        29273.8663528 , 29395.81303233, 29215.72296473, 29473.56744372])

# %%
gen_from_histogram = b1k_preunfolded["b1kGen"].to_numpy()[0]
gen_from_histogram
# Out:
# array([29045.99796112, 29167.02510377, 29155.78057308, 28954.37147581,
#        29075.99688186, 29253.0642014 , 29107.02223828, 29154.65144256,
#        29100.78883557, 29142.35230945, 29261.65178884, 29065.03466746,
#        29178.07281687, 29170.74941395, 29136.45270789, 29283.924991  ,
#        29395.20943281, 29152.2313455 , 29219.4155765 , 29257.90930911,
#        29273.8663528 , 29395.81303233, 29215.72296473, 29473.56744372])

# %%
gen_from_projection == gen_from_histogram
# Out:
# array([False, False,  True, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False,  True])

# %%
delta_gen = np.divide((gen_from_projection - gen_from_histogram), gen_from_histogram)
delta_gen = abs(delta_gen) * 100
delta_gen
# Out:
# array([8.76742183e-14, 1.24729169e-14, 0.00000000e+00, 1.25645235e-14,
#        1.25119659e-14, 3.73086947e-14, 4.99945172e-14, 0.00000000e+00,
#        3.75039195e-14, 3.74504306e-14, 1.24325818e-14, 2.50333698e-14,
#        2.49363886e-14, 1.24713245e-14, 1.24860045e-14, 2.48462514e-14,
#        0.00000000e+00, 2.49584930e-14, 2.49011059e-14, 3.73025164e-14,
#        2.48547887e-14, 2.47516801e-14, 1.24521266e-14, 0.00000000e+00])

# %%
plt.plot(gen_from_projection, label="From projection")
plt.plot(gen_from_histogram , label="From histogram")
plt.xlabel("bins")
plt.legend()

# %%
plt.plot(np.divide(gen_from_projection, gen_from_histogram))
plt.plot(np.ones(len(gen_from_projection)))
plt.ylabel("Projection/Histogram")
plt.xlabel("bins")
plt.ylim(0.94,1.04)
# Out:
# (0.94, 1.04)

# %%
sum(delta_gen)/ len(delta_gen)
# Out:
# 2.2871159074108683e-14

# %% [markdown]
# ### Reco

# %%
reco_from_projection = b1k_preunfolded["b1kRespMat"].to_hist().project('yaxis').to_numpy()[0]
reco_from_projection
# Out:
# array([1062.43303398, 1282.52504609, 1504.73653952, 1677.01323946,
#        1794.91746661, 1878.03405121, 2038.99060494, 2096.01384419,
#        2182.75929417, 2227.76734661, 2268.56713284, 2327.82437562,
#        2375.02893018, 2381.24851083, 2446.96293143, 2494.56007801,
#        2500.54487145, 2534.62501402, 2531.13292986, 2561.89363719,
#        2537.45433284, 2584.78743551, 2602.53768796, 2586.6863304 ,
#        2591.42146728, 2605.00335906, 2638.01319994, 2639.78413253,
#        2657.23944899, 2680.41782051, 2711.3777842 , 2732.81590527,
#        2815.74870693, 2767.49759037, 2824.78096793, 2865.9687355 ,
#        2907.31908172, 2964.34813483, 3030.87913383, 3055.9554344 ,
#        3105.01845476, 3184.57999043, 3242.70427685, 3370.67674566,
#        3488.24672161, 3577.73804187, 3733.8285548 , 3868.93990938])

# %%
reco_from_histogram = b1k_preunfolded["b1kReco"].to_numpy()[0]
reco_from_histogram
# Out:
# array([1062.43303398, 1282.52504609, 1504.73653952, 1677.01323946,
#        1794.91746661, 1878.03405121, 2038.99060494, 2096.01384419,
#        2182.75929417, 2227.76734661, 2268.56713284, 2327.82437562,
#        2375.02893018, 2381.24851083, 2446.96293143, 2494.56007801,
#        2500.54487145, 2534.62501402, 2531.13292986, 2561.89363719,
#        2537.45433284, 2584.78743551, 2602.53768796, 2586.6863304 ,
#        2591.42146728, 2605.00335906, 2638.01319994, 2639.78413253,
#        2657.23944899, 2680.41782051, 2711.3777842 , 2732.81590527,
#        2815.74870693, 2767.49759037, 2824.78096793, 2865.9687355 ,
#        2907.31908172, 2964.34813483, 3030.87913383, 3055.9554344 ,
#        3105.01845476, 3184.57999043, 3242.70427685, 3370.67674566,
#        3488.24672161, 3577.73804187, 3733.8285548 , 3868.93990938])

# %%
reco_from_projection == reco_from_histogram
# Out:
# array([False, False,  True,  True, False, False, False,  True, False,
#        False, False, False, False,  True,  True, False,  True, False,
#        False, False, False, False,  True, False,  True,  True, False,
#         True,  True, False, False, False,  True,  True, False,  True,
#        False,  True, False,  True,  True, False,  True,  True, False,
#        False, False,  True])

# %%
delta_reco = np.divide((reco_from_projection - reco_from_histogram), reco_from_histogram)
delta_reco = abs(delta_reco) * 100
delta_reco
# Out:
# array([2.14012242e-14, 1.77285953e-14, 0.00000000e+00, 0.00000000e+00,
#        2.53352792e-14, 2.42140099e-14, 1.11512861e-14, 0.00000000e+00,
#        2.08336005e-14, 2.04126949e-14, 2.00455761e-14, 1.95352947e-14,
#        1.91470236e-14, 0.00000000e+00, 0.00000000e+00, 1.82295610e-14,
#        0.00000000e+00, 3.58828109e-14, 1.79661584e-14, 3.55008767e-14,
#        3.58428008e-14, 1.75932204e-14, 0.00000000e+00, 1.75803052e-14,
#        0.00000000e+00, 0.00000000e+00, 1.72382515e-14, 0.00000000e+00,
#        0.00000000e+00, 1.69655398e-14, 1.67718181e-14, 1.66402483e-14,
#        0.00000000e+00, 0.00000000e+00, 1.60984995e-14, 0.00000000e+00,
#        1.56414669e-14, 0.00000000e+00, 1.50038101e-14, 0.00000000e+00,
#        0.00000000e+00, 1.42796649e-14, 0.00000000e+00, 0.00000000e+00,
#        1.30365593e-14, 1.27104708e-14, 1.21791171e-14, 0.00000000e+00])

# %%
sum(delta_reco)/ len(delta_reco)
# Out:
# 1.1353453418717617e-14

# %%
plt.plot(reco_from_projection, label="From projection")
plt.plot(reco_from_histogram , label="From histogram")
plt.xlabel("bins")
plt.legend()

# %%
plt.plot(np.divide(reco_from_projection, reco_from_histogram))
plt.plot(np.ones(len(reco_from_projection)))
plt.ylabel("Projection/Histogram")
plt.xlabel("bins")
plt.ylim(0.99,1.01)
# Out:
# (0.99, 1.01)

# %%
RespMat = b1k_preunfolded["b1kRespMat"].to_hist()

# %%
# plot2d_full
plt.figure(figsize=(8, 8))

RespMat.plot2d_full(
    main_cmap="coolwarm",
    top_ls="--",
    top_color="orange",
    top_lw=2,
    side_ls=":",
    side_lw=2,
    side_color="steelblue",
)

plt.show()
# Out:
# /home/bakshi3/.conda/envs/cent7/2020.11-py38/venv/lib/python3.10/site-packages/mplhep/utils.py:211: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   warnings.warn(
# /home/bakshi3/.conda/envs/cent7/2020.11-py38/venv/lib/python3.10/site-packages/mplhep/utils.py:211: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   warnings.warn(
