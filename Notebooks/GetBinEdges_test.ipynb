# %%
import ROOT
import uproot
import numpy as np
import matplotlib.pyplot as plt

# %%
binFileName = "/depot/cms/top/bakshi3/TopSpinCorr_Run2_generalized_ND/CMSSW_10_6_30/src/TopAnalysis/Configuration/analysis/diLeptonic/binning/c_kk_mttbar_binning_rebinnedB.xml"
parser      = ROOT.TDOMParser()
parser.ParseFile(binFileName)

XMLdocument      = parser.GetXMLDocument()
generatorBinning = ROOT.TUnfoldBinningXML.ImportXML(XMLdocument,"generator_rebinnedB")
binning          = generatorBinning.FindNode("ttbargen_rebinnedB")

# %%
binning.GetDistributionBinning(0).Print()
# Out:
# Vector (7)  is as follows
#
#      |        1  |
# ------------------
#    0 |-1
#    1 |-0.666666
#    2 |-0.333332
#    3 |2e-06
#    4 |0.333336
#    5 |0.66667
#    6 |1

# %%
binning.GetDistributionBinning(1).Print()
# Out:
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |250
#    1 |450
#    2 |600
#    3 |800
#    4 |2000

# %%
binning.GetDistributionBinning(1)
# Out:
# <cppyy.gbl.TVectorT<double> object at 0x5566423a18b0>

# %%
fileptr = uproot.open('BootstrapCorrelationMatrices.root')
fileptr.keys()
# Out:
# ['hAllVarUnfClone_rebinnedA;1',
#  'hAllVarUnfClone_rebinnedB;1',
#  'hAllVarUnfCorrected_rebinnedA;1',
#  'hAllVarUnfCorrected_rebinnedB;1',
#  'h_RhoVV_rebinnedA_Afb0;1',
#  'h_RhoVV_rebinnedA_Afb1;1',
#  'h_RhoVV_rebinnedA_Afb2;1',
#  'h_RhoVV_rebinnedA_BinSum;1',
#  'h_RhoVV_rebinnedA_Coef;1',
#  'h_RhoVV_rebinnedA_Afb;1',
#  'h_RhoBB_rebinnedA;1',
#  'h_RhoVBVB_rebinnedA;1',
#  'h_RhoAA_rebinnedA;1',
#  'h_RhoBSBS_rebinnedA;1',
#  'h_RhoCC_rebinnedA;1',
#  'h_RhoABAB_rebinnedA;1',
#  'h_RhoA0A0_rebinnedA;1',
#  'h_RhoA1A1_rebinnedA;1',
#  'h_RhoA2A2_rebinnedA;1',
#  'h_RhoVV_rebinnedB_Afb0;1',
#  'h_RhoVV_rebinnedB_Afb1;1',
#  'h_RhoVV_rebinnedB_Afb2;1',
#  'h_RhoVV_rebinnedB_BinSum;1',
#  'h_RhoVV_rebinnedB_Coef;1',
#  'h_RhoVV_rebinnedB_Afb;1',
#  'h_RhoBB_rebinnedB;1',
#  'h_RhoVBVB_rebinnedB;1',
#  'h_RhoAA_rebinnedB;1',
#  'h_RhoBSBS_rebinnedB;1',
#  'h_RhoCC_rebinnedB;1',
#  'h_RhoABAB_rebinnedB;1',
#  'h_RhoA0A0_rebinnedB;1',
#  'h_RhoA1A1_rebinnedB;1',
#  'h_RhoA2A2_rebinnedB;1',
#  'h_RhoVVCorrected_rebinnedA_Afb0;1',
#  'h_RhoVVCorrected_rebinnedA_Afb1;1',
#  'h_RhoVVCorrected_rebinnedA_Afb2;1',
#  'h_RhoVVCorrected_rebinnedA_BinSum;1',
#  'h_RhoVVCorrected_rebinnedA_Coef;1',
#  'h_RhoVVCorrected_rebinnedA_Afb;1',
#  'h_RhoBBCorrected_rebinnedA;1',
#  'h_RhoVBVBCorrected_rebinnedA;1',
#  'h_RhoAACorrected_rebinnedA;1',
#  'h_RhoBSBSCorrected_rebinnedA;1',
#  'h_RhoCCCorrected_rebinnedA;1',
#  'h_RhoABABCorrected_rebinnedA;1',
#  'h_RhoA0A0Corrected_rebinnedA;1',
#  'h_RhoA1A1Corrected_rebinnedA;1',
#  'h_RhoA2A2Corrected_rebinnedA;1',
#  'h_RhoVVCorrected_rebinnedB_Afb0;1',
#  'h_RhoVVCorrected_rebinnedB_Afb1;1',
#  'h_RhoVVCorrected_rebinnedB_Afb2;1',
#  'h_RhoVVCorrected_rebinnedB_BinSum;1',
#  'h_RhoVVCorrected_rebinnedB_Coef;1',
#  'h_RhoVVCorrected_rebinnedB_Afb;1',
#  'h_RhoBBCorrected_rebinnedB;1',
#  'h_RhoVBVBCorrected_rebinnedB;1',
#  'h_RhoAACorrected_rebinnedB;1',
#  'h_RhoBSBSCorrected_rebinnedB;1',
#  'h_RhoCCCorrected_rebinnedB;1',
#  'h_RhoABABCorrected_rebinnedB;1',
#  'h_RhoA0A0Corrected_rebinnedB;1',
#  'h_RhoA1A1Corrected_rebinnedB;1',
#  'h_RhoA2A2Corrected_rebinnedB;1']

# %%
fileptr['hAllVarUnfClone_rebinnedA'].to_hist().plot()
# Out:
# /home/bakshi3/.conda/envs/cent7/2020.11-py38/venv/lib/python3.10/site-packages/mplhep/utils.py:211: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   warnings.warn(
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f104babc6d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
fileptr['hAllVarUnfCorrected_rebinnedA'].to_hist().plot()
# Out:
# /home/bakshi3/.conda/envs/cent7/2020.11-py38/venv/lib/python3.10/site-packages/mplhep/utils.py:211: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   warnings.warn(
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f10437288b0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
fileptr['h_RhoVV_rebinnedA_Afb'].to_hist().plot()
# Out:
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f104339e410>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f104339e830>, text=[])
